# %%
import numpy as np
import pandas as pd
from chefboost import Chefboost as chef

# %%
training_df = pd.read_csv('Homework/hw3/hw3.4.5_training.csv')
test_df = pd.read_csv('Homework/hw3/hw3.4.5_test.csv')
training_df = pd.DataFrame(training_df)
test_df = pd.DataFrame(test_df)
training_df
# Out:
#      ID              Opponent Is_Home_or_Away Is_Opponent_in_AP25 _Preseason  \
# 0     1                 Texas            Home                            Out
# 1     2              Virginia            Away                            Out
# 2     3          Georgia Tech            Home                             In
# 3     4                 UMass            Home                            Out
# 4     5               Clemson            Away                             In
# 5     6                  Navy            Home                            Out
# 6     7                   USC            Home                             In
# 7     8                Temple            Away                            Out
# 8     9                  PITT            Away                            Out
# 9    10           Wake Forest            Home                            Out
# 10   11        Boston College            Away                            Out
# ...

# %%
training_df = training_df.iloc[0:24, 3:7]
training_df
# Out:
#    Is_Opponent_in_AP25 _Preseason   Media Decision
# 0                             Out   1-NBC      Yes
# 1                             Out   4-ABC      Yes
# 2                              In   1-NBC      Yes
# 3                             Out   1-NBC      Yes
# 4                              In   4-ABC       No
# 5                             Out   1-NBC      Yes
# 6                              In   1-NBC      Yes
# 7                             Out   4-ABC      Yes
# 8                             Out   4-ABC      Yes
# 9                             Out   1-NBC      Yes
# 10                            Out   1-NBC      Yes
# 11                             In   3-FOX       No
# 12                            Out   4-ABC       No
# 13                            Out   1-NBC      Yes
# 14                            Out   1-NBC       No
# 15                            Out   1-NBC       No
# 16                            Out  2-ESPN      Yes
# ...

# %%
config = {'algorithm': 'ID3'}
model = chef.fit(training_df, config)
# Out:
# ID3  tree is going to be built...
# Accuracy:  75.0 % on  24  instances
# finished in  0.33601903915405273  seconds

# %%
for index, instance in test_df.iloc[:, 3:6].iterrows():
    prediction = chef.predict(model, instance)
    print(prediction)
# Out:
# Yes
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# Yes
# No

# %%
config = {'algorithm': 'C4.5'}
model = chef.fit(training_df, config)
# Out:
# C4.5  tree is going to be built...
# Accuracy:  75.0 % on  24  instances
# finished in  0.33678293228149414  seconds

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation


X = test_df.iloc[0:24, 2:7] # Features
y =  test_df.iloc[:, 6:7]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-3d80a2da8541> in <module>
#       2
#       3 # Train Decision Tree Classifer
# ----> 4 clf = clf.fit(X_train,y_train)
#       5
#       6 #Predict the response for test dataset
#
# ~\anaconda\Anaconda3\envs\pythondata\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# ~\anaconda\Anaconda3\envs\pythondata\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     128         random_state = check_random_state(self.random_state)
#     129         if check_input:
# ...
